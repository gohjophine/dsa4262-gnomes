# %%
import json
import pandas as pd
import numpy as np

# %% [markdown]
# # Parse JSON File

# %%
input_path = '../data/data.json'
output_path = '../data/data.csv'
# input_path = '../data/dataset1.json'
# output_path = '../data/data1.csv'
# input_path = '../data/dataset2.json'
# output_path = '../data/data2.csv'

# %%
with open(input_path, 'r') as read_file:
    data = [json.loads(l) for l in read_file]

# %%
# return the key and value of the dictionary separately
# input: dictionary
# output: key, value
def split(x):
    key = list(x.keys())[0]
    value = x.get(key)
    return key, value

# %%
# expand the nested dictionary
transcript_list, position_list, sevenmers_list, reads_list = [], [], [], []
for line in data:
    t, dic = split(line)
    p, dic = split(dic)
    s, reads = split(dic)
    
    for read in reads:
        transcript_list.append(t)
        position_list.append(p)
        sevenmers_list.append(s)
        reads_list.append(read)

# %%
df = pd.DataFrame.from_dict({'transcript_id': transcript_list, 
                             'transcript_position': position_list, 
                             'sevenmers': sevenmers_list, 
                             'reads': reads_list})
df
# Out:
#          transcript_id transcript_position sevenmers  \
# 0      ENST00000000233                 244   AAGACCA
# 1      ENST00000000233                 244   AAGACCA
# 2      ENST00000000233                 244   AAGACCA
# 3      ENST00000000233                 244   AAGACCA
# 4      ENST00000000233                 244   AAGACCA
# ...                ...                 ...       ...
# 74544  ENST00000081029                1771   GAAACCC
# 74545  ENST00000081029                1771   GAAACCC
# 74546  ENST00000081029                1771   GAAACCC
# 74547  ENST00000081029                1771   GAAACCC
# 74548  ENST00000081029                1771   GAAACCC
#
#                                                    reads
# 0      [0.00299, 2.06, 125.0, 0.0177, 10.4, 122.0, 0....
# 1      [0.00631, 2.53, 125.0, 0.00844, 4.67, 126.0, 0...
# 2      [0.00465, 3.92, 109.0, 0.0136, 12.0, 124.0, 0....
# 3      [0.00398, 2.06, 125.0, 0.0083, 5.01, 130.0, 0....
# 4      [0.00664, 2.92, 120.0, 0.00266, 3.94, 129.0, 0...
# ...                                                  ...
# 74544  [0.0102, 3.59, 109.0, 0.00398, 3.33, 106.0, 0....
# 74545  [0.00764, 3.69, 104.0, 0.00232, 4.28, 94.4, 0....
# 74546  [0.0083, 5.47, 105.0, 0.00332, 1.8, 88.4, 0.00...
# 74547  [0.0159, 3.65, 103.0, 0.00564, 3.22, 89.9, 0.0...
# 74548  [0.0116, 5.46, 105.0, 0.00332, 1.53, 90.4, 0.0...
#
# [74549 rows x 4 columns]

# %% [markdown]
# # Expand reads

# %%
df1 = pd.DataFrame(df['reads'].to_list())
df3 = pd.concat([df.reset_index(), df1], axis=1)
df3
# Out:
#        index    transcript_id transcript_position sevenmers  \
# 0          0  ENST00000000233                 244   AAGACCA
# 1          1  ENST00000000233                 244   AAGACCA
# 2          2  ENST00000000233                 244   AAGACCA
# 3          3  ENST00000000233                 244   AAGACCA
# 4          4  ENST00000000233                 244   AAGACCA
# ...      ...              ...                 ...       ...
# 74544  74544  ENST00000081029                1771   GAAACCC
# 74545  74545  ENST00000081029                1771   GAAACCC
# 74546  74546  ENST00000081029                1771   GAAACCC
# 74547  74547  ENST00000081029                1771   GAAACCC
# 74548  74548  ENST00000081029                1771   GAAACCC
#
#                                                    reads        0     1  \
# 0      [0.00299, 2.06, 125.0, 0.0177, 10.4, 122.0, 0....  0.00299  2.06
# 1      [0.00631, 2.53, 125.0, 0.00844, 4.67, 126.0, 0...  0.00631  2.53
# 2      [0.00465, 3.92, 109.0, 0.0136, 12.0, 124.0, 0....  0.00465  3.92
# 3      [0.00398, 2.06, 125.0, 0.0083, 5.01, 130.0, 0....  0.00398  2.06
# 4      [0.00664, 2.92, 120.0, 0.00266, 3.94, 129.0, 0...  0.00664  2.92
# ...                                                  ...      ...   ...
# 74544  [0.0102, 3.59, 109.0, 0.00398, 3.33, 106.0, 0....  0.01020  3.59
# 74545  [0.00764, 3.69, 104.0, 0.00232, 4.28, 94.4, 0....  0.00764  3.69
# 74546  [0.0083, 5.47, 105.0, 0.00332, 1.8, 88.4, 0.00...  0.00830  5.47
# 74547  [0.0159, 3.65, 103.0, 0.00564, 3.22, 89.9, 0.0...  0.01590  3.65
# 74548  [0.0116, 5.46, 105.0, 0.00332, 1.53, 90.4, 0.0...  0.01160  5.46
#
#            2        3      4      5        6      7     8
# 0      125.0  0.01770  10.40  122.0  0.00930  10.90  84.1
# 1      125.0  0.00844   4.67  126.0  0.01030   6.30  80.9
# 2      109.0  0.01360  12.00  124.0  0.00498   2.13  79.6
# 3      125.0  0.00830   5.01  130.0  0.00498   3.78  80.4
# 4      120.0  0.00266   3.94  129.0  0.01300   7.15  82.2
# ...      ...      ...    ...    ...      ...    ...   ...
# 74544  109.0  0.00398   3.33  106.0  0.00335   1.57  88.9
# 74545  104.0  0.00232   4.28   94.4  0.01060   2.62  84.1
# 74546  105.0  0.00332   1.80   88.4  0.00996   2.63  85.1
# 74547  103.0  0.00564   3.22   89.9  0.01260   1.88  89.3
# 74548  105.0  0.00332   1.53   90.4  0.01230   2.49  86.8
#
# [74549 rows x 14 columns]

# %%
df3 = df3.rename(columns = {0:'dwelling_time_1', 1:'sd_current_1', 2:'mean_current_1',
                            3:'dwelling_time_2', 4:'sd_current_2', 5:'mean_current_2',
                            6:'dwelling_time_3', 7:'sd_current_3', 8:'mean_current_3'})
df3
# Out:
#        index    transcript_id transcript_position sevenmers  \
# 0          0  ENST00000000233                 244   AAGACCA
# 1          1  ENST00000000233                 244   AAGACCA
# 2          2  ENST00000000233                 244   AAGACCA
# 3          3  ENST00000000233                 244   AAGACCA
# 4          4  ENST00000000233                 244   AAGACCA
# ...      ...              ...                 ...       ...
# 74544  74544  ENST00000081029                1771   GAAACCC
# 74545  74545  ENST00000081029                1771   GAAACCC
# 74546  74546  ENST00000081029                1771   GAAACCC
# 74547  74547  ENST00000081029                1771   GAAACCC
# 74548  74548  ENST00000081029                1771   GAAACCC
#
#                                                    reads  dwelling_time_1  \
# 0      [0.00299, 2.06, 125.0, 0.0177, 10.4, 122.0, 0....          0.00299
# 1      [0.00631, 2.53, 125.0, 0.00844, 4.67, 126.0, 0...          0.00631
# 2      [0.00465, 3.92, 109.0, 0.0136, 12.0, 124.0, 0....          0.00465
# 3      [0.00398, 2.06, 125.0, 0.0083, 5.01, 130.0, 0....          0.00398
# 4      [0.00664, 2.92, 120.0, 0.00266, 3.94, 129.0, 0...          0.00664
# ...                                                  ...              ...
# 74544  [0.0102, 3.59, 109.0, 0.00398, 3.33, 106.0, 0....          0.01020
# 74545  [0.00764, 3.69, 104.0, 0.00232, 4.28, 94.4, 0....          0.00764
# 74546  [0.0083, 5.47, 105.0, 0.00332, 1.8, 88.4, 0.00...          0.00830
# 74547  [0.0159, 3.65, 103.0, 0.00564, 3.22, 89.9, 0.0...          0.01590
# 74548  [0.0116, 5.46, 105.0, 0.00332, 1.53, 90.4, 0.0...          0.01160
#
#        sd_current_1  mean_current_1  dwelling_time_2  sd_current_2  \
# 0              2.06           125.0          0.01770         10.40
# 1              2.53           125.0          0.00844          4.67
# 2              3.92           109.0          0.01360         12.00
# 3              2.06           125.0          0.00830          5.01
# 4              2.92           120.0          0.00266          3.94
# ...             ...             ...              ...           ...
# 74544          3.59           109.0          0.00398          3.33
# 74545          3.69           104.0          0.00232          4.28
# 74546          5.47           105.0          0.00332          1.80
# 74547          3.65           103.0          0.00564          3.22
# 74548          5.46           105.0          0.00332          1.53
#
#        mean_current_2  dwelling_time_3  sd_current_3  mean_current_3
# 0               122.0          0.00930         10.90            84.1
# 1               126.0          0.01030          6.30            80.9
# 2               124.0          0.00498          2.13            79.6
# 3               130.0          0.00498          3.78            80.4
# 4               129.0          0.01300          7.15            82.2
# ...               ...              ...           ...             ...
# 74544           106.0          0.00335          1.57            88.9
# 74545            94.4          0.01060          2.62            84.1
# 74546            88.4          0.00996          2.63            85.1
# 74547            89.9          0.01260          1.88            89.3
# 74548            90.4          0.01230          2.49            86.8
#
# [74549 rows x 14 columns]

# %%
final_df = df3.drop(columns=['reads', 'index'])
final_df
# Out:
#          transcript_id transcript_position sevenmers  dwelling_time_1  \
# 0      ENST00000000233                 244   AAGACCA          0.00299
# 1      ENST00000000233                 244   AAGACCA          0.00631
# 2      ENST00000000233                 244   AAGACCA          0.00465
# 3      ENST00000000233                 244   AAGACCA          0.00398
# 4      ENST00000000233                 244   AAGACCA          0.00664
# ...                ...                 ...       ...              ...
# 74544  ENST00000081029                1771   GAAACCC          0.01020
# 74545  ENST00000081029                1771   GAAACCC          0.00764
# 74546  ENST00000081029                1771   GAAACCC          0.00830
# 74547  ENST00000081029                1771   GAAACCC          0.01590
# 74548  ENST00000081029                1771   GAAACCC          0.01160
#
#        sd_current_1  mean_current_1  dwelling_time_2  sd_current_2  \
# 0              2.06           125.0          0.01770         10.40
# 1              2.53           125.0          0.00844          4.67
# 2              3.92           109.0          0.01360         12.00
# 3              2.06           125.0          0.00830          5.01
# 4              2.92           120.0          0.00266          3.94
# ...             ...             ...              ...           ...
# 74544          3.59           109.0          0.00398          3.33
# 74545          3.69           104.0          0.00232          4.28
# 74546          5.47           105.0          0.00332          1.80
# 74547          3.65           103.0          0.00564          3.22
# 74548          5.46           105.0          0.00332          1.53
#
#        mean_current_2  dwelling_time_3  sd_current_3  mean_current_3
# 0               122.0          0.00930         10.90            84.1
# 1               126.0          0.01030          6.30            80.9
# 2               124.0          0.00498          2.13            79.6
# 3               130.0          0.00498          3.78            80.4
# 4               129.0          0.01300          7.15            82.2
# ...               ...              ...           ...             ...
# 74544           106.0          0.00335          1.57            88.9
# 74545            94.4          0.01060          2.62            84.1
# 74546            88.4          0.00996          2.63            85.1
# 74547            89.9          0.01260          1.88            89.3
# 74548            90.4          0.01230          2.49            86.8
#
# [74549 rows x 12 columns]

# %% [markdown]
# # Export to csv

# %%
final_df.to_csv(output_path, index=False)
